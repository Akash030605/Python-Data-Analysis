# %%
df["Experience"] = df["present_year"]-df["YOJ"]

# %%
df
# Out:
#   employee  age  salary  package   YOJ  present_year  Experience
# 0        a   32   24500   294000  2001          2024          23
# 1        b   36   25000   300000  2007          2024          17
# 2        c   34   29000   348000  2005          2024          19
# 3        d   35   30000   360000  2007          2024          17
# 4        e   30   45000   540000  2010          2024          14

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df["employee"],df["salary"])
plt.xlabel("Names")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(df["salary"],df["package"])
plt.plot(df["salary"],df["package"])
plt.show()

# %% [markdown]
# # New

# %%
df = pd.read_csv("car_done.csv")

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              157 non-null    int64
#  1   Manufacturer            157 non-null    object
#  2   Model                   157 non-null    object
#  3   Sales_in_thousands      157 non-null    float64
#  4   four_year_resale_value  121 non-null    float64
#  5   Vehicle_type            157 non-null    object
#  6   Price_in_thousands      155 non-null    float64
#  7   Engine_size             156 non-null    float64
#  8   Horsepower              156 non-null    float64
#  9   Wheelbase               156 non-null    float64
#  10  Width                   156 non-null    float64
#  11  Length                  156 non-null    float64
#  12  Curb_weight             155 non-null    float64
#  13  Fuel_capacity           156 non-null    float64
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0  Manufacturer  Model  Sales_in_thousands  \
# 0         False         False  False               False
# 1         False         False  False               False
# 2         False         False  False               False
# 3         False         False  False               False
# 4         False         False  False               False
# ..          ...           ...    ...                 ...
# 152       False         False  False               False
# 153       False         False  False               False
# 154       False         False  False               False
# 155       False         False  False               False
# 156       False         False  False               False
#
#      four_year_resale_value  Vehicle_type  Price_in_thousands  Engine_size  \
# 0                     False         False               False        False
# 1                     False         False               False        False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Manufacturer               0
# Model                      0
# Sales_in_thousands         0
# four_year_resale_value    36
# Vehicle_type               0
# Price_in_thousands         2
# Engine_size                1
# Horsepower                 1
# Wheelbase                  1
# Width                      1
# Length                     1
# Curb_weight                2
# Fuel_capacity              1
# Fuel_efficiency            3
# Latest_Launch              0
# Power_perf_factor          2
# dtype: int64

# %%
#total missing values in the data
df.isnull().sum().sum()
# Out:
# 51

# %%
df.head()
# Out:
#    Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0           0        Acura  Integra              16.919
# 1           1        Acura       TL              39.384
# 2           2        Acura       CL              14.114
# 3           3        Acura       RL               8.588
# 4           4         Audi       A4              20.397
#
#    four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                  16.360    Passenger               21.50          1.8
# 1                  19.875    Passenger               28.40          3.2
# 2                  18.225    Passenger                 NaN          3.2
# 3                  29.725    Passenger               42.00          3.5
# 4                  22.255    Passenger               23.99          1.8
#
#    Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0           0        Acura  Integra              16.919
# 1           1        Acura       TL              39.384
# 2           2        Acura       CL              14.114
# 3           3        Acura       RL               8.588
# 4           4         Audi       A4              20.397
# 5           5         Audi       A6              18.780
# 6           6         Audi       A8               1.380
# 7           7          BMW     323i              19.747
# 8           8          BMW     328i               9.231
# 9           9          BMW     528i              17.527
#
#    four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                  16.360    Passenger               21.50          1.8
# 1                  19.875    Passenger               28.40          3.2
# 2                  18.225    Passenger                 NaN          3.2
# ...

# %% [markdown]
# # column stats

# %%
print("Sales column")
print(df["Sales_in_thousands"].mean())
print("minimum value",df["Sales_in_thousands"].min())
print("maximum",df["Sales_in_thousands"].max())
print("median",df["Sales_in_thousands"].median())
print("std",df["Sales_in_thousands"].std())
# Out:
# Sales column
# 52.99807643312102
# minimum value 0.11
# maximum 540.561
# median 29.45
# std 68.02942199750512

# %%
print("4year Resale-value column")
print(df["four_year_resale_value"].mean())
print("minimum value",
      df["four_year_resale_value"].min())
print("maximum",
      df["four_year_resale_value"].max())
print("median",
      df["four_year_resale_value"].median())
print("std",
      df["four_year_resale_value"].std())
# Out:
# 4year Resale-value column
# 18.07297520661157
# minimum value 5.16
# maximum 67.55
# median 14.18
# std 11.453384099225005

# %%
print("Curb weight column")
print(df["Curb_weight"].mean())
print("minimum value",
      df["Curb_weight"].min())
print("maximum",
      df["Curb_weight"].max())
print("median",
      df["Curb_weight"].median())
print("std",
      df["Curb_weight"].std())
# Out:
# Curb weight column
# 3.378025806451613
# minimum value 1.895
# maximum 5.572
# median 3.342
# std 0.6305016344292964

# %%
print("Engine size column")
print(df["Engine_size"].mean())
print("minimum value",
      df["Engine_size"].min())
print("maximum",
      df["Engine_size"].max())
print("median",
      df["Engine_size"].median())
print("std",
      df["Engine_size"].std())
# Out:
# Engine size column
# 3.0608974358974357
# minimum value 1.0
# maximum 8.0
# median 3.0
# std 1.0446529732758283

# %%
print("Fuel capacity column")
print(df["Fuel_capacity"].mean())
print("minimum value",
      df["Fuel_capacity"].min())
print("maximum",
      df["Fuel_capacity"].max())
print("median",
      df["Fuel_capacity"].median())
print("std",
      df["Fuel_capacity"].std())
# Out:
# Fuel capacity column
# 17.951923076923077
# minimum value 10.3
# maximum 32.0
# median 17.2
# std 3.887921264864631

# %%
print("Fuel efficiency column")
print(df["Fuel_efficiency"].mean())
print("minimum value",
      df["Fuel_efficiency"].min())
print("maximum",
      df["Fuel_efficiency"].max())
print("median",
      df["Fuel_efficiency"].median())
print("std",
      df["Fuel_efficiency"].std())
# Out:
# Fuel efficiency column
# 23.844155844155843
# minimum value 15.0
# maximum 45.0
# median 24.0
# std 4.282705561885176

# %%
print("Horsepower column")
print(df["Horsepower"].mean())
print("minimum value",
      df["Horsepower"].min())
print("maximum",
      df["Horsepower"].max())
print("median",
      df["Horsepower"].median())
print("std",
      df["Horsepower"].std())
# Out:
# Horsepower column
# 185.94871794871796
# minimum value 55.0
# maximum 450.0
# median 177.5
# std 56.70032085837359

# %%
print("Length column")
print(df["Length"].mean())
print("minimum value",
      df["Length"].min())
print("maximum",
      df["Length"].max())
print("median",
      df["Length"].median())
print("std",
      df["Length"].std())
# Out:
# Length column
# 187.34358974358975
# minimum value 149.4
# maximum 224.5
# median 187.9
# std 13.431754284516824

# %%
print("power perf factor column")
print(df["Power_perf_factor"].mean())
print("minimum value",
      df["Power_perf_factor"].min())
print("maximum",
      df["Power_perf_factor"].max())
print("median",
      df["Power_perf_factor"].median())
print("std",
      df["Power_perf_factor"].std())
# Out:
# power perf factor column
# 77.0435912007742
# minimum value 23.27627233
# maximum 188.144323
# median 72.03091719
# std 25.14266409918279

# %%
print("Wheelbase column")
print(df["Wheelbase"].mean())
print("minimum value",
      df["Wheelbase"].min())
print("maximum",
      df["Wheelbase"].max())
print("median",
      df["Wheelbase"].median())
print("std",
      df["Wheelbase"].std())
# Out:
# Wheelbase column
# 107.48717948717946
# minimum value 92.6
# maximum 138.7
# median 107.0
# std 7.641303029809964

# %%
print("Price column")
print(df["Price_in_thousands"].mean())
print("minimum value",
      df["Price_in_thousands"].min())
print("maximum",
      df["Price_in_thousands"].max())
print("median",
      df["Price_in_thousands"].median())
print("std",
      df["Price_in_thousands"].std())
# Out:
# Price column
# 27.390754838709682
# minimum value 9.235
# maximum 85.5
# median 22.799
# std 14.351653189238549

# %%
print("Width column")
print(df["Width"].mean())
print("minimum value",
      df["Width"].min())
print("maximum",
      df["Width"].max())
print("median",
      df["Width"].median())
print("std",
      df["Width"].std())
# Out:
# Width column
# 71.15
# minimum value 62.6
# maximum 79.9
# median 70.55
# std 3.4518718624593676

# %% [markdown]
# # Data Visualization

# %%
plt.bar(df["Model"],df["Sales_in_thousands"])
plt.xlabel("Model")
plt.ylabel("Sales")
plt.show()

# %%
df["Sales_in_thousands"].describe()
# Out:
# count    157.000000
# mean      52.998076
# std       68.029422
# min        0.110000
# 25%       14.114000
# 50%       29.450000
# 75%       67.956000
# max      540.561000
# Name: Sales_in_thousands, dtype: float64

# %%
df.describe()
# Out:
#        Unnamed: 0  Sales_in_thousands  four_year_resale_value  \
# count  157.000000          157.000000              121.000000
# mean    78.000000           52.998076               18.072975
# std     45.466105           68.029422               11.453384
# min      0.000000            0.110000                5.160000
# 25%     39.000000           14.114000               11.260000
# 50%     78.000000           29.450000               14.180000
# 75%    117.000000           67.956000               19.875000
# max    156.000000          540.561000               67.550000
#
#        Price_in_thousands  Engine_size  Horsepower   Wheelbase       Width  \
# count          155.000000   156.000000  156.000000  156.000000  156.000000
# mean            27.390755     3.060897  185.948718  107.487179   71.150000
# std             14.351653     1.044653   56.700321    7.641303    3.451872
# min              9.235000     1.000000   55.000000   92.600000   62.600000
# ...

# %% [markdown]
# # Unique Value

# %%
df.nunique()
# Out:
# Unnamed: 0                157
# Manufacturer               30
# Model                     156
# Sales_in_thousands        157
# four_year_resale_value    117
# Vehicle_type                2
# Price_in_thousands        152
# Engine_size                31
# Horsepower                 66
# Wheelbase                  88
# Width                      78
# Length                    127
# Curb_weight               147
# Fuel_capacity              55
# Fuel_efficiency            20
# Latest_Launch             130
# Power_perf_factor         154
# dtype: int64

# %%
df["Manufacturer"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
df["Manufacturer"].nunique()
# Out:
# 30

# %%
df["Engine_size"].unique()
# Out:
# array([1.8, 3.2, 3.5, 2.8, 4.2, 2.5, 3.1, 3.8, 4.6, 3. , 5.7, 2.2, 3.4,
#        1. , 2.7, 2. , nan, 8. , 5.2, 3.9, 2.4, 4. , 1.6, 2.3, 1.5, 4.7,
#        5.4, 3.3, 4.3, 5. , 1.9, 2.9])

# %%
df["Vehicle_type"].unique()
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %% [markdown]
# # Value Count

# %%
df["Manufacturer"].value_counts()
# Out:
# Manufacturer
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
# Mitsubishi     7
# Nissan         7
# Chrysler       7
# Volvo          6
# Oldsmobile     6
# Lexus          6
# Mercury        6
# Pontiac        6
# Volkswagen     6
# Saturn         5
# Cadillac       5
# Honda          5
# Plymouth       4
# Acura          4
# Buick          4
# Audi           3
# Jeep           3
# Porsche        3
# Hyundai        3
# BMW            3
# Lincoln        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: count, dtype: int64

# %%
df["Vehicle_type"].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15,4))
df["Manufacturer"].value_counts().plot.bar()
plt.show()

# %%
df
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.scatter(df["Horsepower"],df["Price_in_thousands"])
plt.xlabel("HP")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df["Engine_size"],df["Horsepower"])
plt.xlabel("Engine")
plt.ylabel("HP")
plt.show()

# %%
plt.scatter(df["Engine_size"],df["Price_in_thousands"])
plt.xlabel("Engine")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df["Power_perf_factor"],
           df["Width"])
plt.xlabel("Power")
plt.ylabel("Width")
plt.show()

# %%
plt.scatter(df["Fuel_capacity"],
           df["Fuel_efficiency"])
plt.xlabel("Fuel Capacity")
plt.ylabel("Fuel Efficiency")


plt.show()

# %%
plt.scatter(df["Price_in_thousands"],
           df["Sales_in_thousands"])
plt.xlabel("Price(1000)")
plt.ylabel("Sales(1000)")
plt.show()

# %%
plt.scatter(df["Fuel_capacity"],
           df["Power_perf_factor"])
plt.xlabel("Fuel")
plt.ylabel("Power")
plt.show()

# %%
plt.scatter(df["Curb_weight"],
           df["Horsepower"])
plt.xlabel("Curbweight")
plt.ylabel("Horsepower")
plt.show()

# %%
plt.figure(figsize = (15,4))
plt.scatter(df["Model"],
            df["Length"])
plt.xlabel("Model")
plt.ylabel("Length")
plt.show()

# %%
plt.figure(figsize = (15,4))
plt.scatter(df["Manufacturer"],
           df["Engine_size"])
plt.xlabel("Manufacturer")
plt.ylabel("Engine Size")
plt.show()

# %%
plt.scatter(df["Latest_Launch"],
           df["Engine_size"])
plt.xlabel("Launch")
plt.ylabel("EngineSize")
plt.show()
